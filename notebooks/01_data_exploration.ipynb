# %%
import sys
import os
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# add project root to PYTHONPATH
project_root = Path.cwd().parents[0]   
sys.path.append(str(project_root))

from src.data.loader import load_raw_prices, preprocess_prices

# %% [markdown]
# Step0. Extract raw data from yfinance

# %%
# !python ../src/data/downloader.py
# Out:
# YF.download() has changed argument auto_adjust default to True
# Empty DataFrame
# Columns: [(Adj Close, DBC), (Adj Close, GLD), (Adj Close, SPY), (Adj Close, TLT), (Adj Close, VNQ), (Close, DBC), (Close, GLD), (Close, SPY), (Close, TLT), (Close, VNQ), (High, DBC), (High, GLD), (High, SPY), (High, TLT), (High, VNQ), (Low, DBC), (Low, GLD), (Low, SPY), (Low, TLT), (Low, VNQ), (Open, DBC), (Open, GLD), (Open, SPY), (Open, TLT), (Open, VNQ), (Volume, DBC), (Volume, GLD), (Volume, SPY), (Volume, TLT), (Volume, VNQ)]
# Index: []
# Saved prices to C:\Users\zhaoj\Desktop_backup\InternProject\Multi-Asset-Strategy\data\raw\multi_asset_prices.csv
# 5 Failed downloads:
# ['DBC', 'GLD', 'VNQ', 'TLT', 'SPY']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
#
# 5 Failed downloads:
# ['DBC', 'TLT', 'GLD', 'VNQ', 'SPY']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')

# %% [markdown]
# step1. read raw and clean data

# %%
raw = load_raw_prices()
clean = preprocess_prices(raw)
clean.head()
# Out:
# Saved cleaned prices to C:\Users\zhaoj\Desktop_backup\InternProject\Multi-Asset-Strategy\data\processed\prices_clean.csv
# Empty DataFrame
# Columns: [DBC, GLD, SPY, TLT, VNQ]
# Index: []
