# %% [markdown]
# 28/11/2025
#
# 1.今天学了怎么调试py，打断点+run iteractive windows实现直接在py就可以调试。
# 或者#%%，但还在尝试。
# 2.学了Deep Wiki。用AI帮助我读github code。还可以直接提出改进项目的建议，在github上。
# 3.还了解到了Obisidian，感觉太nb了，一定要学。
# 研究还是用obisidian。
# 代码日志可以直接ipynb+commit。但研究journal还是obisidian，太nb了，避免ipynb变成学术垃圾。
#
# 明天学习
# 1.怎么配置yml文件，直接调用参数，开发级别。
# 2.搞清楚yfinance的用法。
# 3.先刷几个入门的obisidian的教学。
